# %%
import pandas as pd
import numpy as np

def main():
    
    data = pd.read_csv('cleandata.csv')
    # Column for Average Fantasy Points calculated based on columns based on different weights placed on different statline
    # The weights are based off users inputs
    
    fgm = int(input("Enter weights for field goals made: "))
    fga = int(input("Enter weights for field goals attempted: "))
    ftm = int(input("Enter weights for free throws made: "))
    fta = int(input("Enter weights for free throws attempted: "))
    threemade = int(input("Enter weights for 3 pointers made: "))
    threemiss = int(input("Enter weights for 3 pointers missed: "))
    reb = int(input("Enter weights for rebounds: "))
    ast = int(input("Enter weights for assists: "))
    stl = int(input("Enter weights for steals: "))
    blk = int(input("Enter weights for blocks: "))
    to = int(input("Enter weights for turnovers: "))
    pts = int(input("Enter weights for points: "))
    
    data['AFP'] = fgm*data['FG'] - fta*data['FGA'] + ftm*data['FT'] - ftm*data['FTA'] 
    + threemade*data['3P'] - threemiss*(data['3PA'] - data['3P']) + reb*data['TRB'] + ast*data['AST']
    + stl*data['STL'] + blk*data['BLK'] - to*data['TOV'] + pts*data['PTS']
    
    
    position = input("Enter position for list of top fantasy player (PG, SG, SF, PF, C): ")
    
    while(position != "stop"):
        if((position == "PG") or (position == "SG") or (position == "SF") or (position == "PF") or (position == "C")):
            df = data[(data['Pos'] == position) & (data['AFP'] > np.mean(data['AFP']))]
            print(df[['Player', 'AFP']].sort_values(by = 'AFP', ascending = False).head(30))
        position = input("Enter another position or type stop to cancel program: ")

    

if __name__=='__main__':
    main()
# Out:
# Enter weights for field goals made: 1
# Enter weights for field goals attempted: 1
# Enter weights for free throws made: 1
# Enter weights for free throws attempted: 1
# Enter weights for 3 pointers made: 1
# Enter weights for 3 pointers missed: 1
# Enter weights for rebounds: 1
# Enter weights for assists: 1
# Enter weights for steals: 2
# Enter weights for blocks: 1
# Enter weights for turnovers: 1
# Enter weights for points: 1
# Enter position for list of top fantasy player (PG, SG, SF, PF, C): PG
#                     Player  AFP
# 164              Josh Gray -0.5
# 378         Shamorie Ponds -0.5
# 280            Daryl Macon -0.5
# 399        Justin Robinson -0.7
# 551         Derrick Walton -0.8
# 177           Jared Harper -1.0
# 481    Nigel Williams-Goss -1.1
# 282           Josh Magette -1.5
# 47             Jordan Bone -1.5
# 388         Chasson Randle -1.6
# 88             Joe Chealey -1.8
# 111    Matthew Dellavedova -2.0
# 136           Yogi Ferrell -2.3
# 352             Elie Okobo -2.4
# 17        Ryan Arcidiacono -2.4
# 338              Raul Neto -2.4
# 144            Tim Frazier -2.4
# 173             Devon Hall -2.5
# 81            Jevon Carter -2.6
# 101             Quinn Cook -2.8
# 465         Brad Wanamaker -2.9
# 299         T.J. McConnell -2.9
# 7             Kadeem Allen -2.9
# 507          Chris Chiozza -3.0
# 85             Alex Caruso -3.0
# 458           Gabe Vincent -3.2
# 470         Tremont Waters -3.2
# 487           Delon Wright -3.3
# 305      Jordan McLaughlin -3.4
# 488  Justin Wright-Foreman -3.4
# Enter another position or type stop to cancel program: t
# Enter another position or type stop to cancel program: t
# Enter another position or type stop to cancel program: f
# Enter another position or type stop to cancel program: fsdf
# Enter another position or type stop to cancel program: SG
#                      Player  AFP
# 281             J.P. Macura  0.0
# 250            John Konchar -0.6
# 322             Matt Mooney -0.7
# 246            Stanton Kidd -0.8
# 171                Kyle Guy -1.0
# 142          Melvin Frazier -1.1
# 471  Quinndary Weatherspoon -1.1
# 95       Antonius Cleveland -1.1
# 264            Jalen Lecque -1.2
# 66            Charlie Brown -1.3
# 452           Rayjon Tucker -1.4
# 168           Javonte Green -1.6
# 440            Khyri Thomas -1.7
# 265            Courtney Lee -1.7
# 228         DaQuan Jeffries -1.7
# 539            Zach Norvell -1.8
# 259          Romeo Langford -1.8
# 339            Malik Newman -2.0
# 103          Jamal Crawford -2.0
# 293        Garrison Mathews -2.0
# 442             Matt Thomas -2.0
# 96              Amir Coffey -2.0
# 520              Dante Exum -2.1
# 143         Michael Frazier -2.1
# 303         Rodney McGruder -2.2
# 347             David Nwaba -2.2
# 343           Jaylen Nowell -2.2
# 319         Naz Mitrou-Long -2.2
# 453             Evan Turner -2.3
# 183      Shaquille Harrison -2.3
